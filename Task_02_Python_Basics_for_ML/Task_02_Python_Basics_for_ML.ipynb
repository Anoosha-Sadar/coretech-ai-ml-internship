# %% [markdown]
# Task 2: Python Basics for Machine Learning
#
# Name: Anoosha Sadar
#
# AI/ML Internship

# %%
print("Python Basics for Machine Learning")
# Out:
# Python Basics for Machine Learning

# %% [markdown]
# Veriable and Data Types
#
#
#  Examle 1: String

# %%
name= "Anoosha"
print(name)
# Out:
# Anoosha

# %% [markdown]
# Example 2: Integer

# %%
age= 20
print(age)
# Out:
# 20

# %% [markdown]
# Examle 3: Float

# %%
cgpa= 3.5
print(cgpa)
# Out:
# 3.5

# %% [markdown]
# Example 4: Boolean

# %%
is_student= True
print(is_student)
# Out:
# True

# %% [markdown]
# Example 5: List

# %%
subjects=["Maths","Python","ML"]
print(subjects)
# Out:
# ['Maths', 'Python', 'ML']

# %% [markdown]
# Example 6: Tuple

# %%
coordinates= (10,20)
print(coordinates)
# Out:
# (10, 20)

# %% [markdown]
# Example 7: Dictionary

# %%
student={
    "name":"Anoosha", "Age":20
}
print(student)
# Out:
# {'name': 'Anoosha', 'Age': 20}

# %% [markdown]
# ### Operators

# %%
a= 10
b= 5

print("Addition: ",a+b)
print("Subtraction: ",a-b)
print("Multiplication: ",a*b)
print("Division: ",a/b)
print("Floor Division: ",a//b)
print("Modulus: ",a%b)
# Out:
# Addition:  15
# Subtraction:  5
# Multiplication:  50
# Division:  2.0
# Floor Division:  2
# Modulus:  0

# %% [markdown]
# ### Conditional Statements

# %%
marks= 75

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
# Out:
# Grade C

# %% [markdown]
# ### Loops
# Example 1: For loop

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Exampe 2: while loop

# %%
count= 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Functions

# %%
def greet(name):
    print("Hello, " + name + "!")

greet("Anoosha")
# Out:
# Hello, Anoosha!

# %% [markdown]
# ### List Comprehension

# %%
squares= [x**2 for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### NumPy Basics

# %%
import numpy as np

arr= np.array([1,2,3,4,5])
print(arr)
print("Mean:",np.mean(arr))
# Out:
# [1 2 3 4 5]
# Mean: 3.0

# %% [markdown]
# ### Pandas Basics

# %%
import pandas as pd
data= {'Name':['Anoosha','Sadar'],'Age':[20,21]}
df= pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0  Anoosha   20
# 1    Sadar   21

# %% [markdown]
# Display Basic Information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes
# None

# %%
print(df.describe())
# Out:
#              Age
# count   2.000000
# mean   20.500000
# std     0.707107
# min    20.000000
# 25%    20.250000
# 50%    20.500000
# 75%    20.750000
# max    21.000000

# %%
print(df.head())
# Out:
#       Name  Age
# 0  Anoosha   20
# 1    Sadar   21

# %%
print(df.shape)
# Out:
# (2, 2)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age'], dtype='object')

# %% [markdown]
# ### Conclusion

# %%
print("Task 2 Completed Successfully")
# Out:
# Task 2 Completed Successfully
